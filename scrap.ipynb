# %%
import numpy as np
import colorama

def cprint(*args, c="", b="", s="", sep=" ", end="\n", reset=True):
    c = {
        "" : "",
        "k" : colorama.Fore.BLACK,
        "r" : colorama.Fore.RED,
        "g" : colorama.Fore.GREEN,
        "y" : colorama.Fore.YELLOW,
        "b" : colorama.Fore.BLUE,
        "m" : colorama.Fore.MAGENTA,
        "c" : colorama.Fore.CYAN,
        "w" : colorama.Fore.WHITE,
        "reset" : colorama.Fore.RESET,
    }[c]
    b = {
        "" : "",
        "k" : colorama.Back.BLACK,
        "r" : colorama.Back.RED,
        "g" : colorama.Back.GREEN,
        "y" : colorama.Back.YELLOW,
        "b" : colorama.Back.BLUE,
        "m" : colorama.Back.MAGENTA,
        "c" : colorama.Back.CYAN,
        "w" : colorama.Back.WHITE,
        "reset" : colorama.Back.RESET,
    }[b]
    s = {
        "" : "",
        "dim" : colorama.Style.DIM,
        "normal" : colorama.Style.NORMAL,
        "bright" : colorama.Style.BRIGHT,
        "reset_all" : colorama.Style.RESET_ALL,
    }[s]
    msg = c + b + s + sep.join([str(arg) for arg in args])
    if reset:
        msg += colorama.Style.RESET_ALL
    print(msg, end=end)

# %%
### Original table from uproot code
output = """
signal
no_cuts[k]:  1118311.6
n_at_least_1_cluster[k]:  227012.23254417122
n_at_least_2_cluster[k]:  16165.71192034749
n_at_least_1_dt_cluster[k]:  242602.90141374612
n_at_least_1_pass_me1_old[k]:  100067.21130434908
n_at_least_2_pass_me1_old[k]:  2580.6183134928315
n_at_least_1_pass_any_me1[k]:  100067.21130434908
n_at_least_2_pass_any_me1[k]:  10243.33878451636
n_at_least_1_pass_any_me1_l1[k]:  38096.13515952156
n_at_least_2_pass_any_me1_l1[k]:  4456.278452677528
n_at_least_1_pass_me1[k]:  100067.21130434908
n_at_least_2_pass_me1[k]:  2580.6183134928315
n_at_least_1_in_l1_plateau[k]:  38096.13515952156
n_at_least_2_in_l1_plateau[k]:  1547.6462312278454
n_tr_pass_me1_l1[k]:  38096.13515952156
n_pass_me1_l1[k]:  4455.070320832256
n_1CSC_ME1_plateau_0lep[k]:  37860.545782514215
n_pass_0lep_veto[k]:  4406.139962437823
n_pass_jet_veto[k]:  3771.8593346677494
n_pass_muon_veto[k]:  3771.2546575485644
n_pass_time_vetoes[k]:  2814.3963076609984
start awkward
done!
n_pass_hlt[k]:  2814.3963076609984
n_at_least_1_csc_tr[k]:  2814.3963076609984
n_at_least_2_csc_tr[k]:  0.0
n_at_least_1_csc[k]:  2814.3963076609984
n_at_least_2_csc[k]:  14.497855908385482
n_at_least_1_dt[k]:  6.040773427798757
n_at_least_2_dt[k]:  0.0
n_pass_split_cluster_veto[k]:  2521.418630681403
n_pass_blind_b[k]:  463.93144000138113
n_pass_dnn_veto_0p7[k]:  459.7029276098832
n_pass_dnn_veto_0p8[k]:  457.2866129862934
n_pass_dnn_veto_0p9[k]:  411.9807519937681
n_pass_dnn_veto[k]:  361.8423636201546
n_pass_dnn_veto_trigger[k]:  326.8058270446247


data
no_cuts[k]:  14887673.0
n_at_least_1_cluster[k]:  14465084.0
n_at_least_2_cluster[k]:  2316754.0
n_at_least_1_dt_cluster[k]:  1366573.0
n_at_least_1_pass_me1_old[k]:  12679676.0
n_at_least_2_pass_me1_old[k]:  137227.0
n_at_least_1_pass_any_me1[k]:  12679676.0
n_at_least_2_pass_any_me1[k]:  2022748.0
n_at_least_1_pass_any_me1_l1[k]:  7990655.0
n_at_least_2_pass_any_me1_l1[k]:  1236045.0
n_at_least_1_pass_me1[k]:  12679676.0
n_at_least_2_pass_me1[k]:  137227.0
n_at_least_1_in_l1_plateau[k]:  7990655.0
n_at_least_2_in_l1_plateau[k]:  83026.0
n_tr_pass_me1_l1[k]:  7990655.0
n_pass_me1_l1[k]:  1235976.0
n_1CSC_ME1_plateau_0lep[k]:  7934289.0
n_pass_0lep_veto[k]:  1225955.0
n_pass_jet_veto[k]:  1211469.0
n_pass_muon_veto[k]:  1211425.0
n_pass_time_vetoes[k]:  59951.0
start awkward
done!
n_pass_hlt[k]:  58859.0
n_at_least_1_csc_tr[k]:  58859.0
n_at_least_2_csc_tr[k]:  0.0
n_at_least_1_csc[k]:  58859.0
n_at_least_2_csc[k]:  511.0
n_at_least_1_dt[k]:  249.0
n_at_least_2_dt[k]:  32.0
n_pass_split_cluster_veto[k]:  22669.0
n_pass_blind_b[k]:  11671.0
n_pass_dnn_veto_0p7[k]:  11584.0
n_pass_dnn_veto_0p8[k]:  11377.0
n_pass_dnn_veto_0p9[k]:  7764.0
n_pass_dnn_veto[k]:  4402.0
n_pass_dnn_veto_trigger[k]:  1564.0
"""

### fix: uproot code with L1 trigger cluster required to be in-time and without runNum selection in HLT

output = """
signal
no_cuts[k]:  1118311.6
n_at_least_1_cluster[k]:  227012.23254417122
n_at_least_2_cluster[k]:  16165.71192034749
n_at_least_1_dt_cluster[k]:  242602.90141374612
n_at_least_1_pass_me1_old[k]:  100067.21130434908
n_at_least_2_pass_me1_old[k]:  2580.6183134928315
n_at_least_1_pass_any_me1[k]:  100067.21130434908
n_at_least_2_pass_any_me1[k]:  10243.33878451636
n_at_least_1_pass_any_me1_l1[k]:  37754.833227391995
n_at_least_2_pass_any_me1_l1[k]:  4412.180621664183
n_at_least_1_pass_me1[k]:  100067.21130434908
n_at_least_2_pass_me1[k]:  2580.6183134928315
n_at_least_1_in_l1_plateau[k]:  37754.833227391995
n_at_least_2_in_l1_plateau[k]:  1536.168774965578
n_tr_pass_me1_l1[k]:  37754.833227391995
n_pass_me1_l1[k]:  4410.972489818911
n_1CSC_ME1_plateau_0lep[k]:  37521.05299216982
n_pass_0lep_veto[k]:  4363.250670734116
n_pass_jet_veto[k]:  3734.406432535584
n_pass_muon_veto[k]:  3733.802162880765
n_pass_time_vetoes[k]:  2788.4212692554665
start awkward
done!
n_pass_hlt[k]:  2788.4212692554665
n_at_least_1_csc_tr[k]:  2788.4212692554665
n_at_least_2_csc_tr[k]:  0.0
n_at_least_1_csc[k]:  2788.4212692554665
n_at_least_2_csc[k]:  14.497855908385482
n_at_least_1_dt[k]:  6.040773427798757
n_at_least_2_dt[k]:  0.0
n_pass_split_cluster_veto[k]:  2500.275915924776
n_pass_blind_b[k]:  459.7029276098832
n_pass_dnn_veto_0p7[k]:  456.0784302079756
n_pass_dnn_veto_0p8[k]:  453.6621665174315
n_pass_dnn_veto_0p9[k]:  408.3563055249062
n_pass_dnn_veto[k]:  358.2178916847698
n_pass_dnn_veto_trigger[k]:  323.18138057576283


data
no_cuts[k]:  14887673.0
n_at_least_1_cluster[k]:  14465084.0
n_at_least_2_cluster[k]:  2316754.0
n_at_least_1_dt_cluster[k]:  1366573.0
n_at_least_1_pass_me1_old[k]:  12679676.0
n_at_least_2_pass_me1_old[k]:  137227.0
n_at_least_1_pass_any_me1[k]:  12679676.0
n_at_least_2_pass_any_me1[k]:  2022748.0
n_at_least_1_pass_any_me1_l1[k]:  6151861.0
n_at_least_2_pass_any_me1_l1[k]:  942165.0
n_at_least_1_pass_me1[k]:  12679676.0
n_at_least_2_pass_me1[k]:  137227.0
n_at_least_1_in_l1_plateau[k]:  6151861.0
n_at_least_2_in_l1_plateau[k]:  60460.0
n_tr_pass_me1_l1[k]:  6151861.0
n_pass_me1_l1[k]:  942112.0
n_1CSC_ME1_plateau_0lep[k]:  6101947.0
n_pass_0lep_veto[k]:  933393.0
n_pass_jet_veto[k]:  921684.0
n_pass_muon_veto[k]:  921654.0
n_pass_time_vetoes[k]:  45133.0
start awkward
done!
n_pass_hlt[k]:  45055.0
n_at_least_1_csc_tr[k]:  45055.0
n_at_least_2_csc_tr[k]:  0.0
n_at_least_1_csc[k]:  45055.0
n_at_least_2_csc[k]:  323.0
n_at_least_1_dt[k]:  162.0
n_at_least_2_dt[k]:  19.0
n_pass_split_cluster_veto[k]:  17758.0
n_pass_blind_b[k]:  9115.0
n_pass_dnn_veto_0p7[k]:  9053.0
n_pass_dnn_veto_0p8[k]:  8893.0
n_pass_dnn_veto_0p9[k]:  6060.0
n_pass_dnn_veto[k]:  3432.0
n_pass_dnn_veto_trigger[k]:  1237.0
"""

### new: uproot code with ME1 veto on all clusters


### new: uproot code with exactly two csc clusters and zero dt clusters


### new: uproot code with ME1 and exactly 2CSC+0DT

output = """
signal
no_cuts[k]:  1118311.6
n_at_least_1_cluster[k]:  227012.23254417122
n_at_least_2_cluster[k]:  16165.71192034749
n_at_least_1_dt_cluster[k]:  242602.90141374612
n_pass_exactly_2_csc_0_dt[k]:  14920.104762403147
n_at_least_1_pass_me1_old[k]:  9593.95549001947
n_at_least_2_pass_me1_old[k]:  2456.7825582984333
n_at_least_1_pass_any_me1[k]:  9593.95549001947
n_at_least_2_pass_any_me1[k]:  9593.95549001947
n_at_least_1_pass_any_me1_l1[k]:  4153.6359246679385
n_at_least_2_pass_any_me1_l1[k]:  4153.6359246679385
n_at_least_1_pass_me1[k]:  9593.95549001947
n_at_least_2_pass_me1[k]:  2456.7825582984333
n_at_least_1_in_l1_plateau[k]:  4153.6359246679385
n_at_least_2_in_l1_plateau[k]:  1469.7203010825174
n_tr_pass_me1_l1[k]:  4153.6359246679385
n_pass_me1_l1[k]:  1469.1162351598812
n_1CSC_ME1_plateau_0lep[k]:  4108.3299618093215
n_pass_0lep_veto[k]:  1459.450976665522
n_pass_jet_veto[k]:  1437.704195986259
n_pass_muon_veto[k]:  1437.704195986259
n_pass_time_vetoes[k]:  1373.0679198711064
start awkward
done!
n_pass_hlt[k]:  1373.0679198711064
n_at_least_1_csc_tr[k]:  1373.0679198711064
n_at_least_2_csc_tr[k]:  0.0
n_at_least_1_csc[k]:  1373.0679198711064
n_at_least_2_csc[k]:  0.0
n_at_least_1_dt[k]:  0.0
n_at_least_2_dt[k]:  0.0
n_pass_split_cluster_veto[k]:  1245.6073616765264
n_pass_blind_b[k]:  200.55369356032978
n_pass_dnn_veto_0p7[k]:  199.9496149044323
n_pass_dnn_veto_0p8[k]:  198.74145759263737
n_pass_dnn_veto_0p9[k]:  189.07622456480087
n_pass_dnn_veto[k]:  164.91311652868671
n_pass_dnn_veto_trigger[k]:  149.20710967513705


data
no_cuts[k]:  14887673.0
n_at_least_1_cluster[k]:  14465084.0
n_at_least_2_cluster[k]:  2316754.0
n_at_least_1_dt_cluster[k]:  1366573.0
n_pass_exactly_2_csc_0_dt[k]:  1945228.0
n_at_least_1_pass_me1_old[k]:  1702951.0
n_at_least_2_pass_me1_old[k]:  99127.0
n_at_least_1_pass_any_me1[k]:  1702951.0
n_at_least_2_pass_any_me1[k]:  1702951.0
n_at_least_1_pass_any_me1_l1[k]:  828530.0
n_at_least_2_pass_any_me1_l1[k]:  828530.0
n_at_least_1_pass_me1[k]:  1702951.0
n_at_least_2_pass_me1[k]:  99127.0
n_at_least_1_in_l1_plateau[k]:  828530.0
n_at_least_2_in_l1_plateau[k]:  47636.0
n_tr_pass_me1_l1[k]:  828530.0
n_pass_me1_l1[k]:  47629.0
n_1CSC_ME1_plateau_0lep[k]:  821041.0
n_pass_0lep_veto[k]:  47339.0
n_pass_jet_veto[k]:  47066.0
n_pass_muon_veto[k]:  47066.0
n_pass_time_vetoes[k]:  4230.0
start awkward
done!
n_pass_hlt[k]:  4230.0
n_at_least_1_csc_tr[k]:  4230.0
n_at_least_2_csc_tr[k]:  0.0
n_at_least_1_csc[k]:  4230.0
n_at_least_2_csc[k]:  0.0
n_at_least_1_dt[k]:  0.0
n_at_least_2_dt[k]:  0.0
n_pass_split_cluster_veto[k]:  706.0
n_pass_blind_b[k]:  350.0
n_pass_dnn_veto_0p7[k]:  329.0
n_pass_dnn_veto_0p8[k]:  294.0
n_pass_dnn_veto_0p9[k]:  164.0
n_pass_dnn_veto[k]:  89.0
n_pass_dnn_veto_trigger[k]:  33.0
"""


### new: either rdataframe or uproot code with or without 0 lepton requirement


## tight cuts
output = """
signal
no_cuts[k]:  1118311.6
n_at_least_1_cluster[k]:  227012.23254417122
n_at_least_2_cluster[k]:  16165.71192034749
n_at_least_1_dt_cluster[k]:  242602.90141374612
n_pass_exactly_2_csc_0_dt[k]:  14920.104762403147
n_at_least_1_pass_me1_old[k]:  9593.95549001947
n_at_least_2_pass_me1_old[k]:  2456.7825582984333
n_at_least_1_pass_any_me1[k]:  9593.95549001947
n_at_least_2_pass_any_me1[k]:  9593.95549001947
n_at_least_1_pass_any_me1_l1[k]:  4153.6359246679385
n_at_least_2_pass_any_me1_l1[k]:  4153.6359246679385
n_at_least_1_pass_me1[k]:  9593.95549001947
n_at_least_2_pass_me1[k]:  2456.7825582984333
n_at_least_1_in_l1_plateau[k]:  4153.6359246679385
n_at_least_2_in_l1_plateau[k]:  1469.7203010825174
n_tr_pass_me1_l1[k]:  4153.6359246679385
n_pass_me1_l1[k]:  1469.1162351598812
n_1CSC_ME1_plateau_0lep[k]:  4108.3299618093215
n_pass_0lep_veto[k]:  1459.450976665522
n_pass_jet_veto[k]:  1335.6150177389409
n_pass_muon_veto[k]:  1334.406885893669
n_pass_time_vetoes[k]:  1275.2072030822405
start awkward
done!
n_pass_hlt[k]:  1275.2072030822405
n_at_least_1_csc_tr[k]:  1275.2072030822405
n_at_least_2_csc_tr[k]:  0.0
n_at_least_1_csc[k]:  1275.2072030822405
n_at_least_2_csc[k]:  0.0
n_at_least_1_dt[k]:  0.0
n_at_least_2_dt[k]:  0.0
n_pass_split_cluster_veto[k]:  1156.8081430576583
n_pass_blind_b[k]:  185.45176536267755
n_pass_dnn_veto_0p7[k]:  184.84768670678008
n_pass_dnn_veto_0p8[k]:  183.63952939498515
n_pass_dnn_veto_0p9[k]:  174.57836228978468
n_pass_dnn_veto[k]:  151.6234242987269
n_pass_dnn_veto_trigger[k]:  136.52148336781323


data
no_cuts[k]:  14887673.0
n_at_least_1_cluster[k]:  14465084.0
n_at_least_2_cluster[k]:  2316754.0
n_at_least_1_dt_cluster[k]:  1366573.0
n_pass_exactly_2_csc_0_dt[k]:  1945228.0
n_at_least_1_pass_me1_old[k]:  1702951.0
n_at_least_2_pass_me1_old[k]:  99127.0
/usr/local/lib/python3.6/site-packages/awkward/array/jagged.py:1031: RuntimeWarning: invalid value encountered in less
  result = getattr(ufunc, method)(*inputs, **kwargs)
/usr/local/lib/python3.6/site-packages/awkward/array/jagged.py:1031: RuntimeWarning: invalid value encountered in greater
  result = getattr(ufunc, method)(*inputs, **kwargs)
n_at_least_1_pass_any_me1[k]:  1702951.0
n_at_least_2_pass_any_me1[k]:  1702951.0
n_at_least_1_pass_any_me1_l1[k]:  828530.0
n_at_least_2_pass_any_me1_l1[k]:  828530.0
n_at_least_1_pass_me1[k]:  1702951.0
n_at_least_2_pass_me1[k]:  99127.0
n_at_least_1_in_l1_plateau[k]:  828530.0
n_at_least_2_in_l1_plateau[k]:  47636.0
n_tr_pass_me1_l1[k]:  828530.0
n_pass_me1_l1[k]:  47629.0
n_1CSC_ME1_plateau_0lep[k]:  821041.0
n_pass_0lep_veto[k]:  47339.0
n_pass_jet_veto[k]:  35363.0
n_pass_muon_veto[k]:  35361.0
n_pass_time_vetoes[k]:  3023.0
start awkward
done!
n_pass_hlt[k]:  3023.0
n_at_least_1_csc_tr[k]:  3023.0
n_at_least_2_csc_tr[k]:  0.0
n_at_least_1_csc[k]:  3023.0
n_at_least_2_csc[k]:  0.0
n_at_least_1_dt[k]:  0.0
n_at_least_2_dt[k]:  0.0
n_pass_split_cluster_veto[k]:  494.0
n_pass_blind_b[k]:  242.0
n_pass_dnn_veto_0p7[k]:  232.0
n_pass_dnn_veto_0p8[k]:  207.0
n_pass_dnn_veto_0p9[k]:  115.0
n_pass_dnn_veto[k]:  61.0
n_pass_dnn_veto_trigger[k]:  24.0
"""


print("")
print("")

print(f"| {'Selection':^31} | {'S (BR=100%)':^15} | {'Eff. S(%)':^9} | {'B':^15} | {'Eff. B(%)':^9} | {'S/√B':^9} |")
print(f"| {'-'*30}: | {'-'*14}: | {'-'*8}: | {'-'*14}: | {'-'*8}: | {'-'*8}: |")
k, table = "", {}
for line in output.split("\n"):
    if "signal" in line:
        k = "signal"
    elif "data" in line:
        k = "data"
    if k not in table:
        table[k] = []
    if "[k]" not in line:
        continue

    labels = {
        "no_cuts" : "No cuts",
        "n_at_least_1_cluster" : ">= 1 CSC",
        "n_pass_exactly_2_csc_0_dt" : "CSC = 2 and DT = 0",
        # "n_at_least_1_pass_me1_old" : ">= 1 CSC (ME1 old)",
        # "n_at_least_2_pass_me1_old" : ">= 2 CSC (ME1 old)",
        "n_at_least_1_pass_any_me1" : ">= 1 CSC (ME1)",
        "n_at_least_2_pass_any_me1" : ">= 2 CSC (ME1)",
        # "n_at_least_1_pass_me1" : ">= 1 CSC (ME1)",
        # "n_at_least_2_pass_me1" : ">= 2 CSC (ME1)",
        # "n_at_least_1_pass_any_me1_l1" : ">= 1 CSC (any ME1/L1)",
        # "n_at_least_2_pass_any_me1_l1" : ">= 2 CSC (+L1)",
        # "n_at_least_1_in_l1_plateau" : ">= 1 CSC (+L1)",
        # "n_at_least_2_in_l1_plateau" : ">= 2 CSC (+L1)",
        "n_pass_me1_l1" : ">= 2 CSC (+L1)",
        "n_pass_jet_veto" : "**>= 2 CSC (+Jet)**",
        "n_pass_muon_veto" : "**>= 2 CSC (+Muon)**",
        "n_pass_time_vetoes" : "**>= 2 CSC (+Time)**",
        "n_pass_0lep_veto" : ">= 2 CSC (+0L)",
        # "n_1CSC_ME1_plateau_0lep" : ">= 2 CSC (+0L)",
        "n_pass_hlt" : ">= 2 CSC (+HLT)",
        "n_pass_split_cluster_veto" : ">= 2 CSC (+\|Δφ\|>1.8)",
        "n_pass_blind_b" : "**>= 2 CSC (+\|Δφ\|<2.5)**",
        "n_pass_dnn_veto_0p7" : ">= 2 CSC DNN>0.7, blind B",
        "n_pass_dnn_veto_0p8" : ">= 2 CSC DNN>0.8, blind B",
        "n_pass_dnn_veto_0p9" : ">= 2 CSC DNN>0.9, blind B",
        "n_pass_dnn_veto" : "**>= 2 CSC DNN>0.96, blind B**",
    }

    label, value = line.replace("  "," ").split(" ")
    if label[:-4] in labels:
        table[k].append([labels[label[:-4]], float(value)])

last_s, last_b = -1, -1
s_all, b_all = table["signal"][0][1], table["data"][0][1]

for (sl, sv), (bl, bv) in zip(table["signal"], table["data"]):
    assert sl == bl
    # seff, last_s = sv/last_s if last_s>0 else 1, sv
    # beff, last_b = bv/last_b if last_b>0 else 1, bv
    seff, last_s = sv/s_all, sv
    beff, last_b = bv/b_all, bv
    srtb = sv/bv**0.5 if bv else 0
    print(f"| {sl:>31} | {sv:>15,.2f} | {100*seff:>9.3g} | {bv:>15,.2f} | {100*beff:>9.3g} | {srtb:>9,.2f} |")
    if ">= 1 CSC (ME1)" in sl:
        print(f"| {'//':^31} | {'//':^15} | {'//':^9} | {'//':^15} | {'//':^9} | {'//':^9} |")
# Out:
# |            Selection            |   S (BR=100%)   | Eff. S(%) |        B        | Eff. B(%) |   S/√B    |
# | ------------------------------: | --------------: | --------: | --------------: | --------: | --------: |
# |                         No cuts |    1,118,311.60 |       100 |   14,887,673.00 |       100 |    289.83 |
# |                        >= 1 CSC |      227,012.23 |      20.3 |   14,465,084.00 |      97.2 |     59.69 |
# |              CSC = 2 and DT = 0 |       14,920.10 |      1.33 |    1,945,228.00 |      13.1 |     10.70 |
# |                  >= 1 CSC (ME1) |        9,593.96 |     0.858 |    1,702,951.00 |      11.4 |      7.35 |
# |               //                |       //        |    //     |       //        |    //     |    //     |
# |                  >= 2 CSC (ME1) |        9,593.96 |     0.858 |    1,702,951.00 |      11.4 |      7.35 |
# |                  >= 2 CSC (+L1) |        1,469.12 |     0.131 |       47,629.00 |      0.32 |      6.73 |
# ...

# %%
blindb = 185.56/1156.83
136.52/blindb
blindb=242/494
24/blindb
# Out:
# 48.99173553719008
