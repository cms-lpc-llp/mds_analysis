# %%
# %reset -f
# %load_ext autoreload
# %autoreload 2

import ROOT as rt
import numpy as np
from src import CMS_lumi, tdrstyle

tdr = tdrstyle.setTDRStyle()
CMS_lumi.writeExtraText = 0

rt.gStyle.SetOptFit(1011)
rt.gStyle.SetOptStat(0)

wH = 1
Z_MASS = 91.2
gc = []

data_year = 'full'
years = ['Run3_Fall22']
fpath = 'data/raw/ggH_HToSSTobbbb_MH-125_MS-15_ctau-1000_TuneCP5_13TeV-powheg-pythia8_59740pb_weighted_histos.root'

lat = rt.TLatex()
lat.SetTextSize(0.05)
lat.SetTextAlign(11)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
ff = rt.TFile(fpath, "READ")

histos = {}

for k in ff.GetListOfKeys():
    histos[k.GetName()] = ff.Get(k.GetName())
# Out:
# {'abs_cscRechitCluster_match_gLLP_decay_z_raw': <cppyy.gbl.TH1F object at 0x979a030>,
#  'abs_cscRechitCluster_match_gLLP_decay_z_abs_cscRechitCluster_match_gLLP_decay_z_raw': <cppyy.gbl.TH2F object at 0xfd581d0>,
#  'abs_cscRechitCluster_match_gLLP_decay_z_abs_cscRechitCluster_match_gLLP_decay_r_raw': <cppyy.gbl.TH2F object at 0xd265e60>,
#  'abs_cscRechitCluster_match_gLLP_decay_z_abs_gLLP_decay_vertex_z_raw': <cppyy.gbl.TH2F object at 0x96bdd70>,
#  'abs_cscRechitCluster_match_gLLP_decay_z_abs_gLLP_decay_vertex_r_raw': <cppyy.gbl.TH2F object at 0x96bd960>,
#  'abs_cscRechitCluster_match_gLLP_decay_z_nDTRechits_raw': <cppyy.gbl.TH2F object at 0x743bfd0>,
#  'abs_cscRechitCluster_match_gLLP_decay_z_nCscRechits_raw': <cppyy.gbl.TH2F object at 0xcee1210>,
#  'abs_cscRechitCluster_match_gLLP_decay_z_nDtRechitClusters_raw': <cppyy.gbl.TH2F object at 0x94eb690>,
#  'abs_cscRechitCluster_match_gLLP_decay_z_nCscRechitClusters_raw': <cppyy.gbl.TH2F object at 0x8eb5e50>,
# ...
